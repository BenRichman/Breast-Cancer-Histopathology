# %% [markdown]
# # Create .npy Files from IDC Images

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pylab as plt
from progressbar import ProgressBar
from PIL import Image
import random
# %matplotlib inline

# %% [markdown]
# ## Import Images

# %%
import os

folders = []
files = []

for entry in os.scandir('Desktop/IDC_regular_ps50_idx5'):
    if entry.is_dir():
        folders.append(entry.path)
    elif entry.is_file():
        files.append(entry.path)

# print('Folders:')
# print(folders[0:10])
print('Number of patients:')
print(len(folders))
# Out:
# Number of patients:
# 279

# %% [markdown]
# Create Files with path extensions /0 and /1 to each patient folder name

# %%
folder_extensions_0 = []
folder_extensions_1 = []


def add_extensions(folder_names):
    """
    Formats folder names to include 0 for IDC- and 1 for IDC+ images
    """
    for folder in folder_names:
        with_0 = folder + '/0'
        with_1 = folder + '/1'
        folder_extensions_0.append(with_0)
        folder_extensions_1.append(with_1)
    return folder_extensions_0, folder_extensions_1


add_extensions(folders)
# Out:
# (['Desktop/IDC_regular_ps50_idx5/9036/0',
#   'Desktop/IDC_regular_ps50_idx5/10268/0',
#   'Desktop/IDC_regular_ps50_idx5/10257/0',
#   'Desktop/IDC_regular_ps50_idx5/8913/0',
#   'Desktop/IDC_regular_ps50_idx5/13613/0',
#   'Desktop/IDC_regular_ps50_idx5/8914/0',
#   'Desktop/IDC_regular_ps50_idx5/15510/0',
#   'Desktop/IDC_regular_ps50_idx5/10259/0',
#   'Desktop/IDC_regular_ps50_idx5/16165/0',
#   'Desktop/IDC_regular_ps50_idx5/10292/0',
#   'Desktop/IDC_regular_ps50_idx5/12951/0',
#   'Desktop/IDC_regular_ps50_idx5/10261/0',
#   'Desktop/IDC_regular_ps50_idx5/10295/0',
#   'Desktop/IDC_regular_ps50_idx5/9259/0',
#   'Desktop/IDC_regular_ps50_idx5/12750/0',
#   'Desktop/IDC_regular_ps50_idx5/13020/0',
#   'Desktop/IDC_regular_ps50_idx5/16552/0',
#   'Desktop/IDC_regular_ps50_idx5/12905/0',
#   'Desktop/IDC_regular_ps50_idx5/9266/0',
#   'Desktop/IDC_regular_ps50_idx5/16555/0',
#   'Desktop/IDC_regular_ps50_idx5/13018/0',
#   'Desktop/IDC_regular_ps50_idx5/9261/0',
#   'Desktop/IDC_regular_ps50_idx5/9257/0',
#   'Desktop/IDC_regular_ps50_idx5/12934/0',
#   'Desktop/IDC_regular_ps50_idx5/12933/0',
#   'Desktop/IDC_regular_ps50_idx5/9250/0',
#   'Desktop/IDC_regular_ps50_idx5/10260/0',
#   'Desktop/IDC_regular_ps50_idx5/10258/0',
#   'Desktop/IDC_regular_ps50_idx5/10293/0',
#   'Desktop/IDC_regular_ps50_idx5/9037/0',
#   'Desktop/IDC_regular_ps50_idx5/10269/0',
#   'Desktop/IDC_regular_ps50_idx5/16531/0',
#   'Desktop/IDC_regular_ps50_idx5/10256/0',
#   'Desktop/IDC_regular_ps50_idx5/15516/0',
#   'Desktop/IDC_regular_ps50_idx5/12932/0',
#   'Desktop/IDC_regular_ps50_idx5/12935/0',
#   'Desktop/IDC_regular_ps50_idx5/9256/0',
#   'Desktop/IDC_regular_ps50_idx5/16554/0',
#   'Desktop/IDC_regular_ps50_idx5/9260/0',
#   'Desktop/IDC_regular_ps50_idx5/13019/0',
#   'Desktop/IDC_regular_ps50_idx5/16553/0',
#   'Desktop/IDC_regular_ps50_idx5/13021/0',
#   'Desktop/IDC_regular_ps50_idx5/8984/0',
#   'Desktop/IDC_regular_ps50_idx5/9258/0',
#   'Desktop/IDC_regular_ps50_idx5/12751/0',
#   'Desktop/IDC_regular_ps50_idx5/9267/0',
#   'Desktop/IDC_regular_ps50_idx5/12876/0',
#   'Desktop/IDC_regular_ps50_idx5/12882/0',
#   'Desktop/IDC_regular_ps50_idx5/15634/0',
#   'Desktop/IDC_regular_ps50_idx5/12871/0',
#   'Desktop/IDC_regular_ps50_idx5/14188/0',
#   'Desktop/IDC_regular_ps50_idx5/15633/0',
#   'Desktop/IDC_regular_ps50_idx5/9324/0',
#   'Desktop/IDC_regular_ps50_idx5/12878/0',
#   'Desktop/IDC_regular_ps50_idx5/9323/0',
#   'Desktop/IDC_regular_ps50_idx5/9383/0',
#   'Desktop/IDC_regular_ps50_idx5/8867/0',
#   'Desktop/IDC_regular_ps50_idx5/9346/0',
#   'Desktop/IDC_regular_ps50_idx5/9174/0',
#   'Desktop/IDC_regular_ps50_idx5/12822/0',
#   'Desktop/IDC_regular_ps50_idx5/9173/0',
#   'Desktop/IDC_regular_ps50_idx5/9322/0',
#   'Desktop/IDC_regular_ps50_idx5/9325/0',
#   'Desktop/IDC_regular_ps50_idx5/12879/0',
#   'Desktop/IDC_regular_ps50_idx5/14189/0',
#   'Desktop/IDC_regular_ps50_idx5/12870/0',
#   'Desktop/IDC_regular_ps50_idx5/12884/0',
#   'Desktop/IDC_regular_ps50_idx5/12241/0',
#   'Desktop/IDC_regular_ps50_idx5/15632/0',
#   'Desktop/IDC_regular_ps50_idx5/12883/0',
#   'Desktop/IDC_regular_ps50_idx5/12877/0',
#   'Desktop/IDC_regular_ps50_idx5/9126/0',
#   'Desktop/IDC_regular_ps50_idx5/13106/0',
#   'Desktop/IDC_regular_ps50_idx5/12823/0',
#   'Desktop/IDC_regular_ps50_idx5/13591/0',
#   'Desktop/IDC_regular_ps50_idx5/9175/0',
#   'Desktop/IDC_regular_ps50_idx5/12824/0',
#   'Desktop/IDC_regular_ps50_idx5/9347/0',
#   'Desktop/IDC_regular_ps50_idx5/9181/0',
#   'Desktop/IDC_regular_ps50_idx5/9382/0',
#   'Desktop/IDC_regular_ps50_idx5/10307/0',
#   'Desktop/IDC_regular_ps50_idx5/13916/0',
#   'Desktop/IDC_regular_ps50_idx5/10300/0',
#   'Desktop/IDC_regular_ps50_idx5/14306/0',
#   'Desktop/IDC_regular_ps50_idx5/15471/0',
#   'Desktop/IDC_regular_ps50_idx5/16896/0',
#   'Desktop/IDC_regular_ps50_idx5/14156/0',
#   'Desktop/IDC_regular_ps50_idx5/9135/0',
#   'Desktop/IDC_regular_ps50_idx5/12890/0',
#   'Desktop/IDC_regular_ps50_idx5/12897/0',
#   'Desktop/IDC_regular_ps50_idx5/10308/0',
#   'Desktop/IDC_regular_ps50_idx5/10301/0',
#   'Desktop/IDC_regular_ps50_idx5/10306/0',
#   'Desktop/IDC_regular_ps50_idx5/12896/0',
#   'Desktop/IDC_regular_ps50_idx5/14157/0',
#   'Desktop/IDC_regular_ps50_idx5/12891/0',
#   'Desktop/IDC_regular_ps50_idx5/12898/0',
#   'Desktop/IDC_regular_ps50_idx5/14192/0',
#   'Desktop/IDC_regular_ps50_idx5/13458/0',
#   'Desktop/IDC_regular_ps50_idx5/9083/0',
#   'Desktop/IDC_regular_ps50_idx5/9077/0',
#   'Desktop/IDC_regular_ps50_idx5/13460/0',
#   'Desktop/IDC_regular_ps50_idx5/8955/0',
#   'Desktop/IDC_regular_ps50_idx5/12910/0',
#   'Desktop/IDC_regular_ps50_idx5/9041/0',
#   'Desktop/IDC_regular_ps50_idx5/14210/0',
#   'Desktop/IDC_regular_ps50_idx5/14082/0',
#   'Desktop/IDC_regular_ps50_idx5/10274/0',
#   'Desktop/IDC_regular_ps50_idx5/9227/0',
#   'Desktop/IDC_regular_ps50_idx5/10273/0',
#   'Desktop/IDC_regular_ps50_idx5/13402/0',
#   'Desktop/IDC_regular_ps50_idx5/14078/0',
#   'Desktop/IDC_regular_ps50_idx5/9023/0',
#   'Desktop/IDC_regular_ps50_idx5/12911/0',
#   'Desktop/IDC_regular_ps50_idx5/14211/0',
#   'Desktop/IDC_regular_ps50_idx5/13691/0',
#   'Desktop/IDC_regular_ps50_idx5/9078/0',
#   'Desktop/IDC_regular_ps50_idx5/12929/0',
#   'Desktop/IDC_regular_ps50_idx5/13461/0',
#   'Desktop/IDC_regular_ps50_idx5/9076/0',
#   'Desktop/IDC_regular_ps50_idx5/13459/0',
#   'Desktop/IDC_regular_ps50_idx5/16570/0',
#   'Desktop/IDC_regular_ps50_idx5/9022/0',
#   'Desktop/IDC_regular_ps50_idx5/10288/0',
#   'Desktop/IDC_regular_ps50_idx5/9228/0',
#   'Desktop/IDC_regular_ps50_idx5/14079/0',
#   'Desktop/IDC_regular_ps50_idx5/10286/0',
#   'Desktop/IDC_regular_ps50_idx5/13403/0',
#   'Desktop/IDC_regular_ps50_idx5/10272/0',
#   'Desktop/IDC_regular_ps50_idx5/10275/0',
#   'Desktop/IDC_regular_ps50_idx5/13404/0',
#   'Desktop/IDC_regular_ps50_idx5/9226/0',
#   'Desktop/IDC_regular_ps50_idx5/13024/0',
#   'Desktop/IDC_regular_ps50_idx5/8975/0',
#   'Desktop/IDC_regular_ps50_idx5/16569/0',
#   'Desktop/IDC_regular_ps50_idx5/12901/0',
#   'Desktop/IDC_regular_ps50_idx5/9262/0',
#   'Desktop/IDC_regular_ps50_idx5/13023/0',
#   'Desktop/IDC_regular_ps50_idx5/16551/0',
#   'Desktop/IDC_regular_ps50_idx5/9265/0',
#   'Desktop/IDC_regular_ps50_idx5/12906/0',
#   'Desktop/IDC_regular_ps50_idx5/9291/0',
#   'Desktop/IDC_regular_ps50_idx5/12930/0',
#   'Desktop/IDC_regular_ps50_idx5/13688/0',
#   'Desktop/IDC_regular_ps50_idx5/12908/0',
#   'Desktop/IDC_regular_ps50_idx5/9254/0',
#   'Desktop/IDC_regular_ps50_idx5/16534/0',
#   'Desktop/IDC_regular_ps50_idx5/8917/0',
#   'Desktop/IDC_regular_ps50_idx5/15513/0',
#   'Desktop/IDC_regular_ps50_idx5/10253/0',
#   'Desktop/IDC_regular_ps50_idx5/9035/0',
#   'Desktop/IDC_regular_ps50_idx5/10254/0',
#   'Desktop/IDC_regular_ps50_idx5/15514/0',
#   'Desktop/IDC_regular_ps50_idx5/16533/0',
#   'Desktop/IDC_regular_ps50_idx5/13617/0',
#   'Desktop/IDC_regular_ps50_idx5/10262/0',
#   'Desktop/IDC_regular_ps50_idx5/12955/0',
#   'Desktop/IDC_regular_ps50_idx5/16166/0',
#   'Desktop/IDC_regular_ps50_idx5/10291/0',
#   'Desktop/IDC_regular_ps50_idx5/12909/0',
#   'Desktop/IDC_regular_ps50_idx5/9255/0',
#   'Desktop/IDC_regular_ps50_idx5/14209/0',
#   'Desktop/IDC_regular_ps50_idx5/12931/0',
#   'Desktop/IDC_regular_ps50_idx5/13689/0',
#   'Desktop/IDC_regular_ps50_idx5/16550/0',
#   'Desktop/IDC_regular_ps50_idx5/13022/0',
#   'Desktop/IDC_regular_ps50_idx5/12752/0',
#   'Desktop/IDC_regular_ps50_idx5/9290/0',
#   'Desktop/IDC_regular_ps50_idx5/12907/0',
#   'Desktop/IDC_regular_ps50_idx5/13687/0',
#   'Desktop/IDC_regular_ps50_idx5/8980/0',
#   'Desktop/IDC_regular_ps50_idx5/8974/0',
#   'Desktop/IDC_regular_ps50_idx5/13025/0',
#   'Desktop/IDC_regular_ps50_idx5/12900/0',
#   'Desktop/IDC_regular_ps50_idx5/16568/0',
#   'Desktop/IDC_regular_ps50_idx5/12954/0',
#   'Desktop/IDC_regular_ps50_idx5/10264/0',
#   'Desktop/IDC_regular_ps50_idx5/16167/0',
#   'Desktop/IDC_regular_ps50_idx5/10290/0',
#   'Desktop/IDC_regular_ps50_idx5/8918/0',
#   'Desktop/IDC_regular_ps50_idx5/16532/0',
#   'Desktop/IDC_regular_ps50_idx5/13616/0',
#   'Desktop/IDC_regular_ps50_idx5/15515/0',
#   'Desktop/IDC_regular_ps50_idx5/10255/0',
#   'Desktop/IDC_regular_ps50_idx5/10299/0',
#   'Desktop/IDC_regular_ps50_idx5/15512/0',
#   'Desktop/IDC_regular_ps50_idx5/8916/0',
#   'Desktop/IDC_regular_ps50_idx5/8864/0',
#   'Desktop/IDC_regular_ps50_idx5/12810/0',
#   'Desktop/IDC_regular_ps50_idx5/8863/0',
#   'Desktop/IDC_regular_ps50_idx5/12817/0',
#   'Desktop/IDC_regular_ps50_idx5/14321/0',
#   'Desktop/IDC_regular_ps50_idx5/12821/0',
#   'Desktop/IDC_regular_ps50_idx5/12819/0',
#   'Desktop/IDC_regular_ps50_idx5/12826/0',
#   'Desktop/IDC_regular_ps50_idx5/9177/0',
#   'Desktop/IDC_regular_ps50_idx5/9345/0',
#   'Desktop/IDC_regular_ps50_idx5/12886/0',
#   'Desktop/IDC_regular_ps50_idx5/9123/0',
#   'Desktop/IDC_regular_ps50_idx5/12872/0',
#   'Desktop/IDC_regular_ps50_idx5/9124/0',
#   'Desktop/IDC_regular_ps50_idx5/12875/0',
#   'Desktop/IDC_regular_ps50_idx5/12881/0',
#   'Desktop/IDC_regular_ps50_idx5/9320/0',
#   'Desktop/IDC_regular_ps50_idx5/12818/0',
#   'Desktop/IDC_regular_ps50_idx5/16014/0',
#   'Desktop/IDC_regular_ps50_idx5/9344/0',
#   'Desktop/IDC_regular_ps50_idx5/9176/0',
#   'Desktop/IDC_regular_ps50_idx5/12820/0',
#   'Desktop/IDC_regular_ps50_idx5/9178/0',
#   'Desktop/IDC_regular_ps50_idx5/9381/0',
#   'Desktop/IDC_regular_ps50_idx5/15839/0',
#   'Desktop/IDC_regular_ps50_idx5/8865/0',
#   'Desktop/IDC_regular_ps50_idx5/12811/0',
#   'Desktop/IDC_regular_ps50_idx5/9319/0',
#   'Desktop/IDC_regular_ps50_idx5/9321/0',
#   'Desktop/IDC_regular_ps50_idx5/16085/0',
#   'Desktop/IDC_regular_ps50_idx5/12880/0',
#   'Desktop/IDC_regular_ps50_idx5/9125/0',
#   'Desktop/IDC_regular_ps50_idx5/12873/0',
#   'Desktop/IDC_regular_ps50_idx5/12242/0',
#   'Desktop/IDC_regular_ps50_idx5/12626/0',
#   'Desktop/IDC_regular_ps50_idx5/16895/0',
#   'Desktop/IDC_regular_ps50_idx5/14190/0',
#   'Desktop/IDC_regular_ps50_idx5/12869/0',
#   'Desktop/IDC_regular_ps50_idx5/12894/0',
#   'Desktop/IDC_regular_ps50_idx5/14155/0',
#   'Desktop/IDC_regular_ps50_idx5/12867/0',
#   'Desktop/IDC_regular_ps50_idx5/12893/0',
#   'Desktop/IDC_regular_ps50_idx5/10303/0',
#   'Desktop/IDC_regular_ps50_idx5/10304/0',
#   'Desktop/IDC_regular_ps50_idx5/15472/0',
#   'Desktop/IDC_regular_ps50_idx5/14305/0',
#   'Desktop/IDC_regular_ps50_idx5/14154/0',
#   'Desktop/IDC_regular_ps50_idx5/12892/0',
#   'Desktop/IDC_regular_ps50_idx5/14153/0',
#   'Desktop/IDC_regular_ps50_idx5/12895/0',
#   'Desktop/IDC_regular_ps50_idx5/12868/0',
#   'Desktop/IDC_regular_ps50_idx5/14191/0',
#   'Desktop/IDC_regular_ps50_idx5/15840/0',
#   'Desktop/IDC_regular_ps50_idx5/14304/0',
#   'Desktop/IDC_regular_ps50_idx5/15473/0',
#   'Desktop/IDC_regular_ps50_idx5/10305/0',
#   'Desktop/IDC_regular_ps50_idx5/10302/0',
#   'Desktop/IDC_regular_ps50_idx5/13401/0',
#   'Desktop/IDC_regular_ps50_idx5/14081/0',
#   'Desktop/IDC_regular_ps50_idx5/9029/0',
#   'Desktop/IDC_regular_ps50_idx5/10277/0',
#   'Desktop/IDC_regular_ps50_idx5/12947/0',
#   'Desktop/IDC_regular_ps50_idx5/12949/0',
#   'Desktop/IDC_regular_ps50_idx5/10279/0',
#   'Desktop/IDC_regular_ps50_idx5/12748/0',
#   'Desktop/IDC_regular_ps50_idx5/9073/0',
#   'Desktop/IDC_regular_ps50_idx5/8956/0',
#   'Desktop/IDC_regular_ps50_idx5/8951/0',
#   'Desktop/IDC_regular_ps50_idx5/14213/0',
#   'Desktop/IDC_regular_ps50_idx5/13694/0',
#   'Desktop/IDC_regular_ps50_idx5/15903/0',
#   'Desktop/IDC_regular_ps50_idx5/13693/0',
#   'Desktop/IDC_regular_ps50_idx5/12948/0',
#   'Desktop/IDC_regular_ps50_idx5/10278/0',
#   'Desktop/IDC_regular_ps50_idx5/10276/0',
#   'Desktop/IDC_regular_ps50_idx5/10282/0',
#   'Desktop/IDC_regular_ps50_idx5/9225/0',
#   'Desktop/IDC_regular_ps50_idx5/10285/0',
#   'Desktop/IDC_regular_ps50_idx5/13400/0',
#   'Desktop/IDC_regular_ps50_idx5/15902/0',
#   'Desktop/IDC_regular_ps50_idx5/9044/0',
#   'Desktop/IDC_regular_ps50_idx5/13666/0',
#   'Desktop/IDC_regular_ps50_idx5/13692/0',
#   'Desktop/IDC_regular_ps50_idx5/9043/0',
#   'Desktop/IDC_regular_ps50_idx5/8959/0',
#   'Desktop/IDC_regular_ps50_idx5/14212/0',
#   'Desktop/IDC_regular_ps50_idx5/9075/0',
#   'Desktop/IDC_regular_ps50_idx5/9081/0',
#   'Desktop/IDC_regular_ps50_idx5/8950/0',
#   'Desktop/IDC_regular_ps50_idx5/12749/0',
#   'Desktop/IDC_regular_ps50_idx5/13462/0',
#   'Desktop/IDC_regular_ps50_idx5/8957/0'],
#  ['Desktop/IDC_regular_ps50_idx5/9036/1',
#   'Desktop/IDC_regular_ps50_idx5/10268/1',
#   'Desktop/IDC_regular_ps50_idx5/10257/1',
#   'Desktop/IDC_regular_ps50_idx5/8913/1',
#   'Desktop/IDC_regular_ps50_idx5/13613/1',
#   'Desktop/IDC_regular_ps50_idx5/8914/1',
#   'Desktop/IDC_regular_ps50_idx5/15510/1',
#   'Desktop/IDC_regular_ps50_idx5/10259/1',
#   'Desktop/IDC_regular_ps50_idx5/16165/1',
#   'Desktop/IDC_regular_ps50_idx5/10292/1',
#   'Desktop/IDC_regular_ps50_idx5/12951/1',
#   'Desktop/IDC_regular_ps50_idx5/10261/1',
#   'Desktop/IDC_regular_ps50_idx5/10295/1',
#   'Desktop/IDC_regular_ps50_idx5/9259/1',
#   'Desktop/IDC_regular_ps50_idx5/12750/1',
#   'Desktop/IDC_regular_ps50_idx5/13020/1',
#   'Desktop/IDC_regular_ps50_idx5/16552/1',
#   'Desktop/IDC_regular_ps50_idx5/12905/1',
#   'Desktop/IDC_regular_ps50_idx5/9266/1',
#   'Desktop/IDC_regular_ps50_idx5/16555/1',
#   'Desktop/IDC_regular_ps50_idx5/13018/1',
#   'Desktop/IDC_regular_ps50_idx5/9261/1',
#   'Desktop/IDC_regular_ps50_idx5/9257/1',
#   'Desktop/IDC_regular_ps50_idx5/12934/1',
#   'Desktop/IDC_regular_ps50_idx5/12933/1',
#   'Desktop/IDC_regular_ps50_idx5/9250/1',
#   'Desktop/IDC_regular_ps50_idx5/10260/1',
#   'Desktop/IDC_regular_ps50_idx5/10258/1',
#   'Desktop/IDC_regular_ps50_idx5/10293/1',
#   'Desktop/IDC_regular_ps50_idx5/9037/1',
#   'Desktop/IDC_regular_ps50_idx5/10269/1',
#   'Desktop/IDC_regular_ps50_idx5/16531/1',
#   'Desktop/IDC_regular_ps50_idx5/10256/1',
#   'Desktop/IDC_regular_ps50_idx5/15516/1',
#   'Desktop/IDC_regular_ps50_idx5/12932/1',
#   'Desktop/IDC_regular_ps50_idx5/12935/1',
#   'Desktop/IDC_regular_ps50_idx5/9256/1',
#   'Desktop/IDC_regular_ps50_idx5/16554/1',
#   'Desktop/IDC_regular_ps50_idx5/9260/1',
#   'Desktop/IDC_regular_ps50_idx5/13019/1',
#   'Desktop/IDC_regular_ps50_idx5/16553/1',
#   'Desktop/IDC_regular_ps50_idx5/13021/1',
#   'Desktop/IDC_regular_ps50_idx5/8984/1',
#   'Desktop/IDC_regular_ps50_idx5/9258/1',
#   'Desktop/IDC_regular_ps50_idx5/12751/1',
#   'Desktop/IDC_regular_ps50_idx5/9267/1',
#   'Desktop/IDC_regular_ps50_idx5/12876/1',
#   'Desktop/IDC_regular_ps50_idx5/12882/1',
#   'Desktop/IDC_regular_ps50_idx5/15634/1',
#   'Desktop/IDC_regular_ps50_idx5/12871/1',
#   'Desktop/IDC_regular_ps50_idx5/14188/1',
#   'Desktop/IDC_regular_ps50_idx5/15633/1',
#   'Desktop/IDC_regular_ps50_idx5/9324/1',
#   'Desktop/IDC_regular_ps50_idx5/12878/1',
#   'Desktop/IDC_regular_ps50_idx5/9323/1',
#   'Desktop/IDC_regular_ps50_idx5/9383/1',
#   'Desktop/IDC_regular_ps50_idx5/8867/1',
#   'Desktop/IDC_regular_ps50_idx5/9346/1',
#   'Desktop/IDC_regular_ps50_idx5/9174/1',
#   'Desktop/IDC_regular_ps50_idx5/12822/1',
#   'Desktop/IDC_regular_ps50_idx5/9173/1',
#   'Desktop/IDC_regular_ps50_idx5/9322/1',
#   'Desktop/IDC_regular_ps50_idx5/9325/1',
#   'Desktop/IDC_regular_ps50_idx5/12879/1',
#   'Desktop/IDC_regular_ps50_idx5/14189/1',
#   'Desktop/IDC_regular_ps50_idx5/12870/1',
#   'Desktop/IDC_regular_ps50_idx5/12884/1',
#   'Desktop/IDC_regular_ps50_idx5/12241/1',
#   'Desktop/IDC_regular_ps50_idx5/15632/1',
#   'Desktop/IDC_regular_ps50_idx5/12883/1',
#   'Desktop/IDC_regular_ps50_idx5/12877/1',
#   'Desktop/IDC_regular_ps50_idx5/9126/1',
#   'Desktop/IDC_regular_ps50_idx5/13106/1',
#   'Desktop/IDC_regular_ps50_idx5/12823/1',
#   'Desktop/IDC_regular_ps50_idx5/13591/1',
#   'Desktop/IDC_regular_ps50_idx5/9175/1',
#   'Desktop/IDC_regular_ps50_idx5/12824/1',
#   'Desktop/IDC_regular_ps50_idx5/9347/1',
#   'Desktop/IDC_regular_ps50_idx5/9181/1',
#   'Desktop/IDC_regular_ps50_idx5/9382/1',
#   'Desktop/IDC_regular_ps50_idx5/10307/1',
#   'Desktop/IDC_regular_ps50_idx5/13916/1',
#   'Desktop/IDC_regular_ps50_idx5/10300/1',
#   'Desktop/IDC_regular_ps50_idx5/14306/1',
#   'Desktop/IDC_regular_ps50_idx5/15471/1',
#   'Desktop/IDC_regular_ps50_idx5/16896/1',
#   'Desktop/IDC_regular_ps50_idx5/14156/1',
#   'Desktop/IDC_regular_ps50_idx5/9135/1',
#   'Desktop/IDC_regular_ps50_idx5/12890/1',
#   'Desktop/IDC_regular_ps50_idx5/12897/1',
#   'Desktop/IDC_regular_ps50_idx5/10308/1',
#   'Desktop/IDC_regular_ps50_idx5/10301/1',
#   'Desktop/IDC_regular_ps50_idx5/10306/1',
#   'Desktop/IDC_regular_ps50_idx5/12896/1',
#   'Desktop/IDC_regular_ps50_idx5/14157/1',
#   'Desktop/IDC_regular_ps50_idx5/12891/1',
#   'Desktop/IDC_regular_ps50_idx5/12898/1',
#   'Desktop/IDC_regular_ps50_idx5/14192/1',
#   'Desktop/IDC_regular_ps50_idx5/13458/1',
#   'Desktop/IDC_regular_ps50_idx5/9083/1',
#   'Desktop/IDC_regular_ps50_idx5/9077/1',
#   'Desktop/IDC_regular_ps50_idx5/13460/1',
#   'Desktop/IDC_regular_ps50_idx5/8955/1',
#   'Desktop/IDC_regular_ps50_idx5/12910/1',
#   'Desktop/IDC_regular_ps50_idx5/9041/1',
#   'Desktop/IDC_regular_ps50_idx5/14210/1',
#   'Desktop/IDC_regular_ps50_idx5/14082/1',
#   'Desktop/IDC_regular_ps50_idx5/10274/1',
#   'Desktop/IDC_regular_ps50_idx5/9227/1',
#   'Desktop/IDC_regular_ps50_idx5/10273/1',
#   'Desktop/IDC_regular_ps50_idx5/13402/1',
#   'Desktop/IDC_regular_ps50_idx5/14078/1',
#   'Desktop/IDC_regular_ps50_idx5/9023/1',
#   'Desktop/IDC_regular_ps50_idx5/12911/1',
#   'Desktop/IDC_regular_ps50_idx5/14211/1',
#   'Desktop/IDC_regular_ps50_idx5/13691/1',
#   'Desktop/IDC_regular_ps50_idx5/9078/1',
#   'Desktop/IDC_regular_ps50_idx5/12929/1',
#   'Desktop/IDC_regular_ps50_idx5/13461/1',
#   'Desktop/IDC_regular_ps50_idx5/9076/1',
#   'Desktop/IDC_regular_ps50_idx5/13459/1',
#   'Desktop/IDC_regular_ps50_idx5/16570/1',
#   'Desktop/IDC_regular_ps50_idx5/9022/1',
#   'Desktop/IDC_regular_ps50_idx5/10288/1',
#   'Desktop/IDC_regular_ps50_idx5/9228/1',
#   'Desktop/IDC_regular_ps50_idx5/14079/1',
#   'Desktop/IDC_regular_ps50_idx5/10286/1',
#   'Desktop/IDC_regular_ps50_idx5/13403/1',
#   'Desktop/IDC_regular_ps50_idx5/10272/1',
#   'Desktop/IDC_regular_ps50_idx5/10275/1',
#   'Desktop/IDC_regular_ps50_idx5/13404/1',
#   'Desktop/IDC_regular_ps50_idx5/9226/1',
#   'Desktop/IDC_regular_ps50_idx5/13024/1',
#   'Desktop/IDC_regular_ps50_idx5/8975/1',
#   'Desktop/IDC_regular_ps50_idx5/16569/1',
#   'Desktop/IDC_regular_ps50_idx5/12901/1',
#   'Desktop/IDC_regular_ps50_idx5/9262/1',
#   'Desktop/IDC_regular_ps50_idx5/13023/1',
#   'Desktop/IDC_regular_ps50_idx5/16551/1',
#   'Desktop/IDC_regular_ps50_idx5/9265/1',
#   'Desktop/IDC_regular_ps50_idx5/12906/1',
#   'Desktop/IDC_regular_ps50_idx5/9291/1',
#   'Desktop/IDC_regular_ps50_idx5/12930/1',
#   'Desktop/IDC_regular_ps50_idx5/13688/1',
#   'Desktop/IDC_regular_ps50_idx5/12908/1',
#   'Desktop/IDC_regular_ps50_idx5/9254/1',
#   'Desktop/IDC_regular_ps50_idx5/16534/1',
#   'Desktop/IDC_regular_ps50_idx5/8917/1',
#   'Desktop/IDC_regular_ps50_idx5/15513/1',
#   'Desktop/IDC_regular_ps50_idx5/10253/1',
#   'Desktop/IDC_regular_ps50_idx5/9035/1',
#   'Desktop/IDC_regular_ps50_idx5/10254/1',
#   'Desktop/IDC_regular_ps50_idx5/15514/1',
#   'Desktop/IDC_regular_ps50_idx5/16533/1',
#   'Desktop/IDC_regular_ps50_idx5/13617/1',
#   'Desktop/IDC_regular_ps50_idx5/10262/1',
#   'Desktop/IDC_regular_ps50_idx5/12955/1',
#   'Desktop/IDC_regular_ps50_idx5/16166/1',
#   'Desktop/IDC_regular_ps50_idx5/10291/1',
#   'Desktop/IDC_regular_ps50_idx5/12909/1',
#   'Desktop/IDC_regular_ps50_idx5/9255/1',
#   'Desktop/IDC_regular_ps50_idx5/14209/1',
#   'Desktop/IDC_regular_ps50_idx5/12931/1',
#   'Desktop/IDC_regular_ps50_idx5/13689/1',
#   'Desktop/IDC_regular_ps50_idx5/16550/1',
#   'Desktop/IDC_regular_ps50_idx5/13022/1',
#   'Desktop/IDC_regular_ps50_idx5/12752/1',
#   'Desktop/IDC_regular_ps50_idx5/9290/1',
#   'Desktop/IDC_regular_ps50_idx5/12907/1',
#   'Desktop/IDC_regular_ps50_idx5/13687/1',
#   'Desktop/IDC_regular_ps50_idx5/8980/1',
#   'Desktop/IDC_regular_ps50_idx5/8974/1',
#   'Desktop/IDC_regular_ps50_idx5/13025/1',
#   'Desktop/IDC_regular_ps50_idx5/12900/1',
#   'Desktop/IDC_regular_ps50_idx5/16568/1',
#   'Desktop/IDC_regular_ps50_idx5/12954/1',
#   'Desktop/IDC_regular_ps50_idx5/10264/1',
#   'Desktop/IDC_regular_ps50_idx5/16167/1',
#   'Desktop/IDC_regular_ps50_idx5/10290/1',
#   'Desktop/IDC_regular_ps50_idx5/8918/1',
#   'Desktop/IDC_regular_ps50_idx5/16532/1',
#   'Desktop/IDC_regular_ps50_idx5/13616/1',
#   'Desktop/IDC_regular_ps50_idx5/15515/1',
#   'Desktop/IDC_regular_ps50_idx5/10255/1',
#   'Desktop/IDC_regular_ps50_idx5/10299/1',
#   'Desktop/IDC_regular_ps50_idx5/15512/1',
#   'Desktop/IDC_regular_ps50_idx5/8916/1',
#   'Desktop/IDC_regular_ps50_idx5/8864/1',
#   'Desktop/IDC_regular_ps50_idx5/12810/1',
#   'Desktop/IDC_regular_ps50_idx5/8863/1',
#   'Desktop/IDC_regular_ps50_idx5/12817/1',
#   'Desktop/IDC_regular_ps50_idx5/14321/1',
#   'Desktop/IDC_regular_ps50_idx5/12821/1',
#   'Desktop/IDC_regular_ps50_idx5/12819/1',
#   'Desktop/IDC_regular_ps50_idx5/12826/1',
#   'Desktop/IDC_regular_ps50_idx5/9177/1',
#   'Desktop/IDC_regular_ps50_idx5/9345/1',
#   'Desktop/IDC_regular_ps50_idx5/12886/1',
#   'Desktop/IDC_regular_ps50_idx5/9123/1',
#   'Desktop/IDC_regular_ps50_idx5/12872/1',
#   'Desktop/IDC_regular_ps50_idx5/9124/1',
#   'Desktop/IDC_regular_ps50_idx5/12875/1',
#   'Desktop/IDC_regular_ps50_idx5/12881/1',
#   'Desktop/IDC_regular_ps50_idx5/9320/1',
#   'Desktop/IDC_regular_ps50_idx5/12818/1',
#   'Desktop/IDC_regular_ps50_idx5/16014/1',
#   'Desktop/IDC_regular_ps50_idx5/9344/1',
#   'Desktop/IDC_regular_ps50_idx5/9176/1',
#   'Desktop/IDC_regular_ps50_idx5/12820/1',
#   'Desktop/IDC_regular_ps50_idx5/9178/1',
#   'Desktop/IDC_regular_ps50_idx5/9381/1',
#   'Desktop/IDC_regular_ps50_idx5/15839/1',
#   'Desktop/IDC_regular_ps50_idx5/8865/1',
#   'Desktop/IDC_regular_ps50_idx5/12811/1',
#   'Desktop/IDC_regular_ps50_idx5/9319/1',
#   'Desktop/IDC_regular_ps50_idx5/9321/1',
#   'Desktop/IDC_regular_ps50_idx5/16085/1',
#   'Desktop/IDC_regular_ps50_idx5/12880/1',
#   'Desktop/IDC_regular_ps50_idx5/9125/1',
#   'Desktop/IDC_regular_ps50_idx5/12873/1',
#   'Desktop/IDC_regular_ps50_idx5/12242/1',
#   'Desktop/IDC_regular_ps50_idx5/12626/1',
#   'Desktop/IDC_regular_ps50_idx5/16895/1',
#   'Desktop/IDC_regular_ps50_idx5/14190/1',
#   'Desktop/IDC_regular_ps50_idx5/12869/1',
#   'Desktop/IDC_regular_ps50_idx5/12894/1',
#   'Desktop/IDC_regular_ps50_idx5/14155/1',
#   'Desktop/IDC_regular_ps50_idx5/12867/1',
#   'Desktop/IDC_regular_ps50_idx5/12893/1',
#   'Desktop/IDC_regular_ps50_idx5/10303/1',
#   'Desktop/IDC_regular_ps50_idx5/10304/1',
#   'Desktop/IDC_regular_ps50_idx5/15472/1',
#   'Desktop/IDC_regular_ps50_idx5/14305/1',
#   'Desktop/IDC_regular_ps50_idx5/14154/1',
#   'Desktop/IDC_regular_ps50_idx5/12892/1',
#   'Desktop/IDC_regular_ps50_idx5/14153/1',
#   'Desktop/IDC_regular_ps50_idx5/12895/1',
#   'Desktop/IDC_regular_ps50_idx5/12868/1',
#   'Desktop/IDC_regular_ps50_idx5/14191/1',
#   'Desktop/IDC_regular_ps50_idx5/15840/1',
#   'Desktop/IDC_regular_ps50_idx5/14304/1',
#   'Desktop/IDC_regular_ps50_idx5/15473/1',
#   'Desktop/IDC_regular_ps50_idx5/10305/1',
#   'Desktop/IDC_regular_ps50_idx5/10302/1',
#   'Desktop/IDC_regular_ps50_idx5/13401/1',
#   'Desktop/IDC_regular_ps50_idx5/14081/1',
#   'Desktop/IDC_regular_ps50_idx5/9029/1',
#   'Desktop/IDC_regular_ps50_idx5/10277/1',
#   'Desktop/IDC_regular_ps50_idx5/12947/1',
#   'Desktop/IDC_regular_ps50_idx5/12949/1',
#   'Desktop/IDC_regular_ps50_idx5/10279/1',
#   'Desktop/IDC_regular_ps50_idx5/12748/1',
#   'Desktop/IDC_regular_ps50_idx5/9073/1',
#   'Desktop/IDC_regular_ps50_idx5/8956/1',
#   'Desktop/IDC_regular_ps50_idx5/8951/1',
#   'Desktop/IDC_regular_ps50_idx5/14213/1',
#   'Desktop/IDC_regular_ps50_idx5/13694/1',
#   'Desktop/IDC_regular_ps50_idx5/15903/1',
#   'Desktop/IDC_regular_ps50_idx5/13693/1',
#   'Desktop/IDC_regular_ps50_idx5/12948/1',
#   'Desktop/IDC_regular_ps50_idx5/10278/1',
#   'Desktop/IDC_regular_ps50_idx5/10276/1',
#   'Desktop/IDC_regular_ps50_idx5/10282/1',
#   'Desktop/IDC_regular_ps50_idx5/9225/1',
#   'Desktop/IDC_regular_ps50_idx5/10285/1',
#   'Desktop/IDC_regular_ps50_idx5/13400/1',
#   'Desktop/IDC_regular_ps50_idx5/15902/1',
#   'Desktop/IDC_regular_ps50_idx5/9044/1',
#   'Desktop/IDC_regular_ps50_idx5/13666/1',
#   'Desktop/IDC_regular_ps50_idx5/13692/1',
#   'Desktop/IDC_regular_ps50_idx5/9043/1',
#   'Desktop/IDC_regular_ps50_idx5/8959/1',
#   'Desktop/IDC_regular_ps50_idx5/14212/1',
#   'Desktop/IDC_regular_ps50_idx5/9075/1',
#   'Desktop/IDC_regular_ps50_idx5/9081/1',
#   'Desktop/IDC_regular_ps50_idx5/8950/1',
#   'Desktop/IDC_regular_ps50_idx5/12749/1',
#   'Desktop/IDC_regular_ps50_idx5/13462/1',
#   'Desktop/IDC_regular_ps50_idx5/8957/1'])

# %%
import os

images_0 = []
images_1 = []


def pywalker_0(path):
    """
    Walks files and appends to IDC- list
    """
    for root, dirs, files in os.walk(path):
        for file_ in files:
            images_0.append(os.path.join(root, file_))


def pywalker_1(path):
    """
    Wals files and appends to IDC+ list
    """
    for root, dirs, files in os.walk(path):
        for file_ in files:
            images_1.append(os.path.join(root, file_))


if __name__ == '__main__':
    for filename in folder_extensions_0:
        pywalker_0(filename)

if __name__ == '__main__':
    for filename in folder_extensions_1:
        pywalker_1(filename)

# %%
print(len(images_0))
print(len(images_1))
# Out:
# 198738
# 78786

# %% [markdown]
# ### Identifying how many benign images do not fit the 50x50 pixel requirement

# %%
# Change to apply to all images
sub = images_0[:1000]
how_many_screwups = 0
pbar = ProgressBar()

for x in pbar(range(100)):
    for i in range(len(sub)):
        temp_image = Image.open(sub[i])
        temp = list(temp_image.getdata())
        temp_array = np.array(temp)
        if temp_array.shape != (2500, 3):
            how_many_screwups = how_many_screwups + 1
print(how_many_screwups)
# Out:
# 100% (100 of 100) |######################| Elapsed Time: 0:03:31 Time:  0:03:31
# 5500

# %% [markdown]
# ### Identifying how many malignant images do not fit the 50x50 pixel requirement

# %%
# Change to apply to all images 
sub2 = images_1[:1000]
how_many_screwups2 = 0
pbar2 = ProgressBar()

for x in pbar2(range(100)):
    for i in range(len(sub2)):
        temp_image = Image.open(sub2[i])
        temp = list(temp_image.getdata())
        temp_array = np.array(temp)
        if temp_array.shape != (2500, 3):
            how_many_screwups2 += 1
print(how_many_screwups2)
# Out:
# 100% (100 of 100) |######################| Elapsed Time: 0:03:08 Time:  0:03:08
# 0

# %% [markdown]
# # For Color Images

# %% [markdown]
# ### Create 2d Array of all 50x50 benign images

# %%
images_0_data = []
benign = images_0[:]
for i in range(len(benign)):
    temp_image = Image.open(benign[i])
    temp = list(temp_image.getdata())
    temp_array = np.array(temp)
    if temp_array.shape == (2500, 3):
        data_array = temp_array.reshape(50, 50, 3)
        data = data_array/255
        images_0_data.append(data)
print('Done!')
# Out:
# Done!

# %%
np.save('benign_rgb', images_0_data)
print('Done!')
# Out:
# Done!

# %%
benign_subset = random.sample(images_0_data, 5000)
np.save('benign_subset_rgb', benign_subset)

# %%
benign_subset10k = random.sample(images_0_data, 10000)
np.save('benign_subset_rgb10k', benign_subset10k)

# %% [markdown]
# ### Create 2d Array of all 50x50 malignant images

# %%
images_1_data = []
malignant = images_1[:]
for i in range(len(malignant)):
    temp_image = Image.open(malignant[i])
    temp = list(temp_image.getdata())
    temp_array = np.array(temp)
    if temp_array.shape == (2500, 3):
        data_array = temp_array.reshape(50, 50, 3)
        data = data_array/255
        images_1_data.append(data)
print('Done!')
# Out:
# Done!

# %%
np.save('malignant_rgb', images_1_data)

# %%
malignant_subset = random.sample(images_1_data, 5000)
np.save('malignant_subset_rgb', malignant_subset)

# %%
malignant_subset20k = random.sample(images_1_data, 10000)
np.save('malignant_subset_rgb10k', malignant_subset20k)

# %% [markdown]
# ## For Black and White Images

# %%
images_0_bw = []
benign = images_0[:]
for i in range(len(benign)):
    temp_image = Image.open(benign[i])
    temp_grey = temp_image.convert('L')
    temp = list(temp_grey.getdata())
    temp_array = np.array(temp)
    if temp_array.shape == (2500,):
        data_array = temp_array.reshape(50, 50, 1)
        data = data_array/255
        images_0_bw.append(data)
print('Done!')
# Out:
# Done!

# %%
np.save('benign_grey', images_0_bw)
print('Done!')
# Out:
# Done!

# %%
benign_subset_grey = random.sample(images_0_bw, 10000)
np.save('benign_subset_grey', benign_subset_grey)

# %%
images_1_bw = []
malignant = images_1[:]
for i in range(len(malignant)):
    temp_image = Image.open(malignant[i])
    temp_grey = temp_image.convert('L')
    temp = list(temp_grey.getdata())
    temp_array = np.array(temp)
    if temp_array.shape == (2500,):
        data_array = temp_array.reshape(50, 50, 1)
        data = data_array/255
        images_1_bw.append(data)
print('Done!')
# Out:
# Done!

# %%
np.save('malignant_grey', images_1_bw)

# %%
malignant_subset_grey = random.sample(images_1_bw, 10000)
np.save('malignant_subset_grey', malignant_subset_grey)
